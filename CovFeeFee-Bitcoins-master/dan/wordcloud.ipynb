# %%
import numpy as np
from PIL import Image
from os import path
import matplotlib.pyplot as plt
import os
import random

from wordcloud import WordCloud, STOPWORDS


# get data directory 
d = path.dirname(__file__) if "__file__" in locals() else os.getcwd()

# read the mask image taken from
mask = np.array(Image.open(path.join(d, "./Resources/bitcoin.png")))

# read the json file for words
text = open(path.join(d, './Output/twitterdump.json')).read()


# adding specific stopwords
stopwords = set(STOPWORDS)
stopwords.add("https")
stopwords.add("ud838")
stopwords.add("u2026")
stopwords.add("ud83c")
stopwords.add("ud83d")
stopwords.add("arbitraj")
stopwords.add("arbingtool")
stopwords.add("estonia")
stopwords.add("tallim")
stopwords.add("tallinn")
stopwords.add("co")
stopwords.add("nhttps")


wc = WordCloud(max_words=1000, mask=mask, stopwords=stopwords, margin=10,
               random_state=1).generate(text)

# store default colored image
default_colors = wc.to_array()
wc.to_file("./Output/bitcoinwords.png")
# plt.axis("off")
# plt.figure()
plt.title("Default colors")
plt.imshow(default_colors, interpolation="bilinear")
plt.axis("off")
plt.show()
